# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
columns=["Iteration","Pose_x_y_Theta","Wij_sen1",'Wij_sen2',"Wij_minus_Hij_sen1",'Wij_minus_Hij_sen2',"Cwij","Distance_traveled_by_bot","Total_distance_traveled_by_all","H_Global_locational_Cost"]
df=pd.read_csv('project_schneider_scenario5.csv',usecols=columns)

print(df)
plt.plot(df.Iteration,df.H_Global_locational_Cost)
plt.title("H_Global_locational_Cost, Scenario 5")
plt.xlabel("Iterations")
plt.ylabel('H_Global_locational_Cost')
plt.show()
# Out:
#      Iteration                                     Pose_x_y_Theta  \
# 0            0  [[ 1.3   1.05  1.05 -0.95  0.15]\r\n [ 0.25  0...
# 1            1  [[ 1.29304043  1.04304043  1.04469043 -0.94934...
# 2            2  [[ 1.28541436  1.03541436  1.03890979 -0.94768...
# 3            3  [[ 1.27723147  1.02723147  1.03303336 -0.94537...
# 4            4  [[ 1.26860946  1.01860946  1.02713412 -0.94233...
# ..         ...                                                ...
# 679        679  [[ 1.29870305 -1.49920428 -0.09960216 -0.90050...
# 680        680  [[ 1.29874585 -1.49923054 -0.09961529 -0.89976...
# 681        681  [[ 1.29878723 -1.49925593 -0.09962799 -0.90050...
# 682        682  [[ 1.29882726 -1.49928049 -0.09964027 -0.89976...
# 683        683  [[ 1.29886596 -1.49930423 -0.09965214 -0.90050...
#
#                                               Wij_sen1  \
# 0    [1.0119047619047619, 2.0040983606557377, 1.025...
# 1    [1.0238095238095237, 2.0081967213114753, 1.049...
# ...

# %%
plt.rcParams["figure.figsize"] = [7.00, 3.50]
plt.rcParams["figure.autolayout"] = True
columns=["Iteration","Pose_x_y_Theta","Wij_sen1","Wij_minus_Hij_sen1","Cwij","Distance_traveled_by_bot","Total_distance_traveled_by_all","H_Global_locational_Cost"]
df=pd.read_csv('Scenario1/project_schneider.csv',usecols=columns)

print(df)
plt.plot(df.Iteration,df.H_Global_locational_Cost)
plt.title("H_Global_locational_Cost, Scenario 1")
plt.xlabel("Iterations")
plt.ylabel('H_Global_locational_Cost')
plt.show()
# Out:
#      Iteration                                     Pose_x_y_Theta  \
# 0            0  [[ 1.3   1.05  1.05 -0.95  0.15  0.25 -0.7  -0...
# 1            1  [[ 1.29304043  1.04675293  1.04415817 -0.95004...
# 2            2  [[ 1.28541436  1.04271986  1.03797126 -0.94983...
# 3            3  [[ 1.27723147  1.03828876  1.03148207 -0.94939...
# 4            4  [[ 1.26860946  1.03279166  1.02531097 -0.94875...
# ..         ...                                                ...
# 696        696  [[ 1.16978099  0.30846169  0.30929365 -0.99948...
# 697        697  [[ 1.16989822  0.30862245  0.30942696 -1.00141...
# 698        698  [[ 1.17001158  0.30877791  0.30955587 -0.99945...
# 699        699  [[ 1.1701212   0.30892824  0.30968052 -1.00140...
# 700        700  [[ 1.1702272   0.30907361  0.30980106 -0.99942...
#
#                                               Wij_sen1  \
# 0    [[1.0178571428571428, 1.03125, 1.0161290322580...
# 1    [[1.0378571428571428, 1.0606617647058822, 1.03...
# ...

# %%
df=pd.read_csv('Scenario1/wij_minus_hij1.csv')
plt.plot(df.Iteration,df.bot_1)
plt.plot(df.Iteration,df.bot_2)
plt.plot(df.Iteration,df.bot_3)
plt.plot(df.Iteration,df.bot_4)
plt.plot(df.Iteration,df.bot_5)
plt.title("Wij_minus_hij_Sensor1, Scenario 1")
plt.xlabel("Iterations")
plt.ylabel('Wij_Minus_hij')
plt.show()

# %%
df=pd.read_csv('Scenario1/wij_minus_hij2.csv')
plt.plot(df.Iteration,df.bot_6)
plt.plot(df.Iteration,df.bot_7)
plt.plot(df.Iteration,df.bot_8)
plt.plot(df.Iteration,df.bot_9)
plt.plot(df.Iteration,df.bot_10)
plt.title("Wij_minus_hij_Sensor2, Scenario 1")
plt.xlabel("Iterations")
plt.ylabel('Wij_Minus_hij')
plt.show()
